# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
foodbank_foodinse = plt.imread('./image/Food Bank Geocoordinates in relation to Food Insecurity Rates.PNG')
plt.figure(figsize=(14, 14))
plt.imshow(foodbank_foodinse)

# %%
food_inse_per_state = plt.imread('./image/Food insecurity rate for each state in 2020.png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_per_state)

# %%
food_inse_pie = plt.imread('./image/Food Security Status of U.S. Households with Children in 2020.png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_pie)

# %%
food_inse = plt.imread('./image/food_inse.png')
plt.figure(figsize=(14, 14))
plt.imshow(food_inse)

# %%
overall = plt.imread('./image/overall.png')
plt.figure(figsize=(14, 14))
plt.imshow(overall)

# %%
foodinse_by_race = plt.imread('./image/race.png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_by_race)

# %%
foodinse_by_state = plt.imread('./image/state.png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_by_state)

# %%
foodinse_by_year = plt.imread('./image/Trends in Prevalence Rates of Food Insecurity by Year.png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_by_year)
