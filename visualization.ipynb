# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
food_inse_race = plt.imread('./image/Average Food Insecurity Rate by Race In California In 2020.png')
plt.figure(figsize=(14, 14))
plt.imshow(food_inse_race)

# %%
food_bank_map = plt.imread('./image/Food Bank Geocoordinates On California Map.png')
plt.figure(figsize=(14, 12))
plt.imshow(food_bank_map)

# %%
food_inse_cal = plt.imread('./image/Food Insecurity By California County.png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_cal)

# %%
food_inse_race_line_all = plt.imread('./image/Food Insecurity By Month By Race In 2020 (All Lines).png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_race_line_all)

# %%
food_inse_race_line_black = plt.imread('./image/Food Insecurity By Month By Race In 2020 (Black Peak).png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_race_line_black)

# %%
food_inse_race_line_Nov = plt.imread('./image/Food Insecurity By Month By Race In 2020 (November Lines).png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_race_line_Nov)

# %%
food_inse_race_line = plt.imread('./image/Food Insecurity By Month By Race In 2020.png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_race_line)

# %%
foodinse_by_state = plt.imread('./image/Food Insecurity By State By Race In 2020.png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_by_state)

# %%
food_inse_heatmap = plt.imread('./image/Food Insecurity Rate By State In 2020.png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_heatmap)

# %%
food_inse_pie = plt.imread('./image/Food Security Status of U.S. Households with Children in 2020.png')
plt.figure(figsize=(14, 12))
plt.imshow(food_inse_pie)

# %%
foodinse_race_month_hor = plt.imread('./image/Racial Disparities In Food Insecurity In 2020 (Last Months December Line).png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_race_month_hor)

# %%
foodinse_race_month_Nov = plt.imread('./image/Racial Disparities In Food Insecurity In 2020 (Last Months November Line).png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_race_month_Nov)

# %%
foodinse_race_month = plt.imread('./image/Racial Disparities In Food Insecurity In 2020 (Last Months).png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_race_month)

# %%
foodinse_by_year = plt.imread('./image/Trends in Prevalence Rates of Food Insecurity by Year.png')
plt.figure(figsize=(14, 14))
plt.imshow(foodinse_by_year)
